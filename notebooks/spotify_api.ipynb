# %% [markdown]
# 1.-Load env variables

# %%
from dotenv import load_dotenv
import os

import spotipy
from spotipy.oauth2 import SpotifyOAuth

load_dotenv(override=True)

SPOTIPY_CLIENT_ID = os.getenv("SPOTIPY_CLIENT_ID")
SPOTIPY_CLIENT_SECRET = os.getenv("SPOTIPY_CLIENT_SECRET")
SPOTIPY_REDIRECT_URI = os.getenv("SPOTIPY_REDIRECT_URI")

print(SPOTIPY_CLIENT_ID)
# Out:
# 87283d04dd8042ee8904d85e198ff38f

# %% [markdown]
# 2.- Connection with spotify

# %%
# Configuration with OAuth
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=SPOTIPY_CLIENT_ID,
    client_secret=SPOTIPY_CLIENT_SECRET,
    redirect_uri=SPOTIPY_REDIRECT_URI,  # Same as the one in your app
    scope="playlist-read-private"  # Scope to read private playlists
))

# Get user information
user = sp.current_user()
print(f"User user: {user['display_name']} ({user['id']})")

# Get user's playlists
playlists = sp.current_user_playlists()

print("User's Playlists:")
for playlist in playlists['items']:
    print(f"- {playlist['name']} (ID: {playlist['id']})")
# Out:
# Gtk-Message: 22:47:06.881: Not loading module "atk-bridge": The functionality is provided by GTK natively. Please try to not load it.
#
# (brave:11529): Gtk-WARNING **: 22:47:06.929: GTK+ module /snap/brave/488/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 22:47:06.929: Failed to load module "canberra-gtk-module"
#
# (brave:11529): Gtk-WARNING **: 22:47:06.930: GTK+ module /snap/brave/488/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 22:47:06.930: Failed to load module "canberra-gtk-module"
# ...

# %%
playlists["items"][0]
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/43uxO4ilXiQl8rGcH1wnxU'},
#  'href': 'https://api.spotify.com/v1/playlists/43uxO4ilXiQl8rGcH1wnxU',
#  'id': '43uxO4ilXiQl8rGcH1wnxU',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 60}],
# ...

# %%
playlists["items"][0]
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/43uxO4ilXiQl8rGcH1wnxU'},
#  'href': 'https://api.spotify.com/v1/playlists/43uxO4ilXiQl8rGcH1wnxU',
#  'id': '43uxO4ilXiQl8rGcH1wnxU',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 60}],
# ...

# %%
tracks = sp.playlist_tracks("43uxO4ilXiQl8rGcH1wnxU")
for track in tracks["items"]:
    print(f"- {track['track']['name']} by {track['track']['artists'][0]['name']}")
# Out:
# - Freedom by Pharrell Williams
# - Just a Cloud Away by Pharrell Williams
# - Fun (feat. Chris Brown) by Pitbull
# - Piece By Piece by Pharrell Williams
# - Despicable Me by Pharrell Williams
# - Seven Nation Army by The White Stripes
# - We Will Rock You by Queen
# - Basket Case by Green Day
# - Wellerman - Sea Shanty by Nathan Evans
# - I Love It (feat. Charli XCX) by Icona Pop
# - Para qué me escribes by Hermanos Martínez
# - Belong Together by Mark Ambor
# - B-Side by Khruangbin
# - In The Hall Of The Mountain King by Edvard Grieg
# - La petite fille de la mer - Remastered by Vangelis

# %%
tracks["items"][0]["track"]
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
# ...

# %%
song = sp.track(track["track"]["id"])
song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4P70aqttdpJ9vuYFDmf7f6'},
#     'href': 'https://api.spotify.com/v1/artists/4P70aqttdpJ9vuYFDmf7f6',
#     'id': '4P70aqttdpJ9vuYFDmf7f6',
#     'name': 'Vangelis',
#     'type': 'artist',
#     'uri': 'spotify:artist:4P70aqttdpJ9vuYFDmf7f6'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
# ...

# %%
id = tracks["items"][0]["track"]["id"]
id
# Out:
# '6RB9YvNyP0RZfCUcMtZELH'

# %%
# Configurar la autenticación
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=SPOTIPY_CLIENT_ID,
    client_secret=SPOTIPY_CLIENT_SECRET,
    redirect_uri=SPOTIPY_REDIRECT_URI,  # Same as the one in your app
    scope="user-library-read"  # Permiso para leer información de canciones
))

id = "6RB9YvNyP0RZfCUcMtZELH"

# Obtener detalles del track
track = sp.track(id)

# Obtener características de audio
audio_features = sp.audio_features([id])[0]  # Devuelve una lista, tomamos el primer elemento

# Mostrar información
print(f"🎵 {track['name']} - {track['artists'][0]['name']}")
print(f"📅 Año: {track['album']['release_date'][:4]}")
print(f"🔗 Álbum: {track['album']['name']}")
print(f"🔥 Popularidad: {track['popularity']} / 100")
print(f"🎭 Géneros: {', '.join(track['artists'][0]['genres']) if track['artists'][0].get('genres') else 'Desconocido'}")
print("🎼 Características musicales:")
print(f"   🎚️ BPM: {audio_features['tempo']}")
print(f"   🎸 Energía: {audio_features['energy'] * 100:.1f}%")
print(f"   🎭 Valencia (felicidad): {audio_features['valence'] * 100:.1f}%")
print(f"   🏋️ Densidad de baile: {audio_features['danceability'] * 100:.1f}%")
# Out:
# Se está abriendo en una sesión de navegador existente.
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=6RB9YvNyP0RZfCUcMtZELH with Params: {} returned 403 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/code/personal-spotify/.venv/lib/python3.12/site-packages/spotipy/client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File ~/code/personal-spotify/.venv/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# ...
