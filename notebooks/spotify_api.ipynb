# %% [markdown]
# 1.-Load env variables

# %%
from dotenv import load_dotenv
import os

import spotipy
from spotipy.oauth2 import SpotifyOAuth

load_dotenv(override=True)

SPOTIPY_CLIENT_ID = os.getenv("SPOTIPY_CLIENT_ID")
SPOTIPY_CLIENT_SECRET = os.getenv("SPOTIPY_CLIENT_SECRET")
SPOTIPY_REDIRECT_URI = os.getenv("SPOTIPY_REDIRECT_URI")

print(SPOTIPY_CLIENT_ID)
# Out:
# 87283d04dd8042ee8904d85e198ff38f

# %% [markdown]
# 2.- Connection with spotify

# %%
# Configuration with OAuth
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=SPOTIPY_CLIENT_ID,
    client_secret=SPOTIPY_CLIENT_SECRET,
    redirect_uri=SPOTIPY_REDIRECT_URI,  # Same as the one in your app
    scope="playlist-read-private"  # Scope to read private playlists
))

# Get user information
user = sp.current_user()
print(f"User user: {user['display_name']} ({user['id']})")

# Get user's playlists
playlists = sp.current_user_playlists()

print("User's Playlists:")
for playlist in playlists['items']:
    print(f"- {playlist['name']} (ID: {playlist['id']})")
# Out:
# update.go:85: cannot change mount namespace according to change mount (/var/lib/snapd/hostfs/usr/local/share/doc /usr/local/share/doc none bind,ro 0 0): cannot open directory "/usr/local/share": permission denied
# update.go:85: cannot change mount namespace according to change mount (/var/lib/snapd/hostfs/usr/share/gimp/2.0/help /usr/share/gimp/2.0/help none bind,ro 0 0): cannot write to "/var/lib/snapd/hostfs/usr/share/gimp/2.0/help" because it would affect the host in "/var/lib/snapd"
# update.go:85: cannot change mount namespace according to change mount (/var/lib/snapd/hostfs/usr/share/sphinx_rtd_theme /usr/share/sphinx_rtd_theme none bind,ro 0 0): cannot write to "/var/lib/snapd/hostfs/usr/share/sphinx_rtd_theme" because it would affect the host in "/var/lib/snapd"
# update.go:85: cannot change mount namespace according to change mount (/var/lib/snapd/hostfs/usr/share/xubuntu-docs /usr/share/xubuntu-docs none bind,ro 0 0): cannot write to "/var/lib/snapd/hostfs/usr/share/xubuntu-docs" because it would affect the host in "/var/lib/snapd"
# Gtk-Message: 10:13:07.396: Not loading module "atk-bridge": The functionality is provided by GTK natively. Please try to not load it.
#
# (brave:7249): Gtk-WARNING **: 10:13:07.505: GTK+ module /snap/brave/501/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 10:13:07.505: Failed to load module "canberra-gtk-module"
#
# (brave:7249): Gtk-WARNING **: 10:13:07.506: GTK+ module /snap/brave/501/gnome-platform/usr/lib/gtk-2.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 10:13:07.506: Failed to load module "canberra-gtk-module"
# [7249:7249:0425/101307.987673:ERROR:object_proxy.cc(589)] Failed to call method: org.freedesktop.Secret.Service.ReadAlias: object_path= /org/freedesktop/secrets: org.freedesktop.DBus.Error.AccessDenied: An AppArmor policy prevents this sender from sending this message to this recipient; type="method_call", sender=":1.148" (uid=1000 pid=7249 comm="/snap/brave/501/opt/brave.com/brave/brave https://" label="snap.brave.brave (enforce)") interface="org.freedesktop.Secret.Service" member="ReadAlias" error name="(unset)" requested_reply="0" destination="org.freedesktop.secrets" (uid=1000 pid=2329 comm="/usr/bin/gnome-keyring-daemon --foreground --compo" label="unconfined")
# User user: chrislugram (chrislugram)
# User's Playlists:
# - Para Eidan (ID: 43uxO4ilXiQl8rGcH1wnxU)
# - Guitarras (ID: 52GFKU3q7YfrlN5gSYHwcu)
# - From Weekly Discover (ID: 2GhzbDZOO7cSnCpsV5ynWF)
# - Pharrel Williams (ID: 1XZR8Qq4Z9QBSGmaRw8YIX)
# - Vacaciones 2024 (ID: 4el02h3mAVhWdPY7fHUqzg)
# - Spanish Navidad 2023 (ID: 10KpzFcgIHhcQZTlpsJSyp)
# - Rock Punk 90 & 2000s (ID: 795pkzqNXSnmAdx0bC3HPx)
# - Peacefully (ID: 3wg3sCOSiq5aDBoyyJOGAy)
# - 90s Grunge  (ID: 4wBgVELOP7TIWb3GpmOc1H)
# - Acoustic2 (ID: 38xHI4lD4K90qk1Hvw9BjY)
# - Your Top Songs 2022 (ID: 5ssSVx8Z6zlGfal4zFddAP)
# - 2022 (ID: 2H6NuhzbRc83nQBcS6YQbg)
# - 🌌 northern lights vibes  (ID: 49Z75H3dSzSSeFii9zCMrE)
# - Aurora Borealis  (ID: 638H76xoQ1UDzcS7L5xOr5)
# - Playlist for next travel Sep 2022 (ID: 2nqSts46YqWdFr4LrQLq7U)
# - Tech/Productivity (ID: 69RJ6Js7MQ6Exv35txRNyv)
# - Anime (ID: 3UfPn1sqm9nCf9adssPxa3)
# - Mi lista n.º 25 (ID: 52rDauL5DtntkbU1CZK675)
# - Punk para principiantes: protopunk (ID: 4EN9Gi4pUsMcYqcyLxRMzw)
# - ENNIO (ID: 5Vcrdrl3ZbBCcVUHhW8ZJs)
# - Los años extraordinarios (ID: 2rMj48dBMnndTbv2Extclc)
# - Libro (ID: 55pHzciJBpwN2c08CXhZA7)
# - Japanese Lofi Chill (ID: 0cyH0TxFDgCQ2gQbs6shh2)
# - Recuerdos Verano 2020 (ID: 0HvcZhlR4TOAaYwgAlVDkw)
# - Vacaciones Diciembre (ID: 1qwXTw66pX6LMOz5U5IPie)
# - LOTR (ID: 5MBvpy4D1ZsUbEjTlPtGj7)
# - RealClassics (ID: 4sgzMsRAKHY21rb1hD4DEH)
# - Linkin Park (All) (ID: 5NlKpIK13WMudwv8fIzUUj)
# - Jazz-hop (ID: 2KRV0hlhtfmbPu112iqsVM)
# - DnD Background Music (ID: 0vqGWjT0g9uLni6F8VKv9g)
# - JAPAN CLASSIC (ID: 5yGXXoINnXa6TStKr2tOQF)
# - Videogames (ID: 2lHxfXUim3f6rElhFfYpFp)
# - Regge & Ragga (ID: 1QFzHPjQmIj6vPdgUYQpx7)
# - pablo niccas (ID: 1sSTQFV7ZUbGpMQqdOkgQT)
# - dust in the wind (ID: 5u7mCPGBUIrzy7qZ1dkQWe)
# - Chillhop Radio 🐾 jazz/lofi hip hop beats to study/relax to | Study Music | Chillhop Music 2025 (ID: 0CFuMybe6s77w6QQrJjW7d)
# - Soundtrack for Study (ID: 0hZNf3tcMT4x03FyjKYJ3M)
# - Classics (ID: 2SSVwnqrpJ4hfuDOBH951c)
# - John Williams (ID: 6wYhgiewKH4KjT8NOqTHDY)
# - Libros, Lluvia y Guitarra (ID: 5OtXMSE7hbc9TNYhqczMrN)
# - Deadpool OST (ID: 3qYiprAXABq19JBtZ1d2GR)
# - Inon Zur (ID: 3lWvMooR079iXv4IzZJgoF)
# - Series (ID: 4BEnvvLEJsCEOaJ5WqO422)
# - Cine (ID: 6XkCEFe7KGYPz0Y4P0kWot)
# - Fantasy (ID: 7xU07h8J3ZCm5Lm859QhDA)
# - Ed Sheeran (ID: 3ppPofzi8MGnvzQBrekwsQ)
# - Verano (ID: 5U8mRESFkI9H4jYNifgSH2)
# - Rap Melodico (ID: 4nSETE2BFo1TbYzgAKCVJm)
# - Generic (ID: 5V7VKENcCL1Cp1K6OPdoI6)
# - Electrónica (ID: 4JXKUoIQwl7MPT5Sj0ton5)

# %%
playlists["items"][0]
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/43uxO4ilXiQl8rGcH1wnxU'},
#  'href': 'https://api.spotify.com/v1/playlists/43uxO4ilXiQl8rGcH1wnxU',
#  'id': '43uxO4ilXiQl8rGcH1wnxU',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 60}],
#  'name': 'Para Eidan',
#  'owner': {'display_name': 'chrislugram',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/chrislugram'},
#   'href': 'https://api.spotify.com/v1/users/chrislugram',
#   'id': 'chrislugram',
#   'type': 'user',
#   'uri': 'spotify:user:chrislugram'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAAEEpevJNTxJ68NyMqnga6niASaPHQ',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/43uxO4ilXiQl8rGcH1wnxU/tracks',
#   'total': 15},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:43uxO4ilXiQl8rGcH1wnxU'}

# %%
playlists["items"][0]
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/43uxO4ilXiQl8rGcH1wnxU'},
#  'href': 'https://api.spotify.com/v1/playlists/43uxO4ilXiQl8rGcH1wnxU',
#  'id': '43uxO4ilXiQl8rGcH1wnxU',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d00001e021e340d1480e7bb29a45e3bd7ab67616d00001e027d15f4754a70b55dac6cd56eab67616d00001e02b891567cfc8507b310ce6ab3ab67616d00001e02f3e795a11fd55388843b85c9',
#    'width': 60}],
#  'name': 'Para Eidan',
#  'owner': {'display_name': 'chrislugram',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/chrislugram'},
#   'href': 'https://api.spotify.com/v1/users/chrislugram',
#   'id': 'chrislugram',
#   'type': 'user',
#   'uri': 'spotify:user:chrislugram'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAAFAtPB4CeZxTGu3o/tNEdmdk6B5UO',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/43uxO4ilXiQl8rGcH1wnxU/tracks',
#   'total': 19},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:43uxO4ilXiQl8rGcH1wnxU'}

# %%
import json
from pathlib import Path

data_folder = Path.cwd() / "data"
data_folder.mkdir(exist_ok=True)

# %%
# Download a tracklist

tracklist_example = data_folder / "tracklist_example.json"

with open(tracklist_example, "w") as f:
    json.dump(playlists["items"][0], f)

# %%
tracks = sp.playlist_tracks("43uxO4ilXiQl8rGcH1wnxU")
for track in tracks["items"]:
    print(f"- {track['track']['name']} by {track['track']['artists'][0]['name']}")
# Out:
# - Freedom by Pharrell Williams
# - Just a Cloud Away by Pharrell Williams
# - Fun (feat. Chris Brown) by Pitbull
# - Piece By Piece by Pharrell Williams
# - Despicable Me by Pharrell Williams
# - Seven Nation Army by The White Stripes
# - We Will Rock You by Queen
# - Basket Case by Green Day
# - Wellerman - Sea Shanty by Nathan Evans
# - I Love It (feat. Charli XCX) by Icona Pop
# - Para qué me escribes by Hermanos Martínez
# - Belong Together by Mark Ambor
# - B-Side by Khruangbin
# - In The Hall Of The Mountain King by Edvard Grieg
# - La petite fille de la mer - Remastered by Vangelis
# - Witch Doctor by Cartoons
# - There's Nothing Holdin' Me Back by Shawn Mendes
# - CAN'T STOP THE FEELING! (from DreamWorks Animation's "TROLLS") by Justin Timberlake
# - ELM by Pierre Bensusan

# %%
test = tracks["items"][0]["track"]
# test.pop("available_markets")
test["album"].pop("available_markets")
test
# Out:
# {'preview_url': None,
#  'explicit': False,
#  'type': 'track',
#  'episode': False,
#  'track': True,
#  'album': {'type': 'album',
#   'album_type': 'single',
#   'href': 'https://api.spotify.com/v1/albums/3Aw8a13WJi24hkjRRtMp9n',
#   'id': '3Aw8a13WJi24hkjRRtMp9n',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f3e795a11fd55388843b85c9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f3e795a11fd55388843b85c9',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f3e795a11fd55388843b85c9',
#     'width': 64}],
#   'name': 'Freedom',
#   'release_date': '2015-07-02',
#   'release_date_precision': 'day',
#   'uri': 'spotify:album:3Aw8a13WJi24hkjRRtMp9n',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#     'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#     'id': '2RdwBSPQiwcmiDo9kixcl8',
#     'name': 'Pharrell Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3Aw8a13WJi24hkjRRtMp9n'},
#   'total_tracks': 1},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#    'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#    'id': '2RdwBSPQiwcmiDo9kixcl8',
#    'name': 'Pharrell Williams',
#    'type': 'artist',
#    'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}],
#  'disc_number': 1,
#  'track_number': 1,
#  'duration_ms': 162466,
#  'external_ids': {'isrc': 'USSM11505220'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6RB9YvNyP0RZfCUcMtZELH'},
#  'href': 'https://api.spotify.com/v1/tracks/6RB9YvNyP0RZfCUcMtZELH',
#  'id': '6RB9YvNyP0RZfCUcMtZELH',
#  'name': 'Freedom',
#  'popularity': 70,
#  'uri': 'spotify:track:6RB9YvNyP0RZfCUcMtZELH',
#  'is_local': False}

# %%
song = sp.track(track["track"]["id"])
song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4P70aqttdpJ9vuYFDmf7f6'},
#     'href': 'https://api.spotify.com/v1/artists/4P70aqttdpJ9vuYFDmf7f6',
#     'id': '4P70aqttdpJ9vuYFDmf7f6',
#     'name': 'Vangelis',
#     'type': 'artist',
#     'uri': 'spotify:artist:4P70aqttdpJ9vuYFDmf7f6'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3UNXsFe9kpKxRaKE1hG7TD'},
#   'href': 'https://api.spotify.com/v1/albums/3UNXsFe9kpKxRaKE1hG7TD',
#   'id': '3UNXsFe9kpKxRaKE1hG7TD',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273b2b4c7a5658490324b29a28f',
#     'width': 640,
#     'height': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02b2b4c7a5658490324b29a28f',
#     'width': 300,
#     'height': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851b2b4c7a5658490324b29a28f',
#     'width': 64,
#     'height': 64}],
#   'name': "L'apocalypse des animaux (Remastered)",
#   'release_date': '1973-01-01',
#   'release_date_precision': 'day',
#   'total_tracks': 7,
#   'type': 'album',
#   'uri': 'spotify:album:3UNXsFe9kpKxRaKE1hG7TD'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4P70aqttdpJ9vuYFDmf7f6'},
#    'href': 'https://api.spotify.com/v1/artists/4P70aqttdpJ9vuYFDmf7f6',
#    'id': '4P70aqttdpJ9vuYFDmf7f6',
#    'name': 'Vangelis',
#    'type': 'artist',
#    'uri': 'spotify:artist:4P70aqttdpJ9vuYFDmf7f6'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 354906,
#  'explicit': False,
#  'external_ids': {'isrc': 'FRUM71600720'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/3uNFRvQVEIEsQgHdZFw6Dk'},
#  'href': 'https://api.spotify.com/v1/tracks/3uNFRvQVEIEsQgHdZFw6Dk',
#  'id': '3uNFRvQVEIEsQgHdZFw6Dk',
#  'is_local': False,
#  'name': 'La petite fille de la mer - Remastered',
#  'popularity': 60,
#  'preview_url': None,
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:3uNFRvQVEIEsQgHdZFw6Dk'}

# %%
id = tracks["items"][0]["track"]["id"]
id
# Out:
# '6RB9YvNyP0RZfCUcMtZELH'

# %%
# Configurar la autenticación
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id=SPOTIPY_CLIENT_ID,
    client_secret=SPOTIPY_CLIENT_SECRET,
    redirect_uri=SPOTIPY_REDIRECT_URI,  # Same as the one in your app
    scope="user-library-read"  # Permiso para leer información de canciones
))

# %%
id = "6RB9YvNyP0RZfCUcMtZELH"

# Obtener detalles del track
track = sp.track(id)
track
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#     'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#     'id': '2RdwBSPQiwcmiDo9kixcl8',
#     'name': 'Pharrell Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3Aw8a13WJi24hkjRRtMp9n'},
#   'href': 'https://api.spotify.com/v1/albums/3Aw8a13WJi24hkjRRtMp9n',
#   'id': '3Aw8a13WJi24hkjRRtMp9n',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273f3e795a11fd55388843b85c9',
#     'width': 640,
#     'height': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02f3e795a11fd55388843b85c9',
#     'width': 300,
#     'height': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851f3e795a11fd55388843b85c9',
#     'width': 64,
#     'height': 64}],
#   'name': 'Freedom',
#   'release_date': '2015-07-02',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3Aw8a13WJi24hkjRRtMp9n'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#    'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#    'id': '2RdwBSPQiwcmiDo9kixcl8',
#    'name': 'Pharrell Williams',
#    'type': 'artist',
#    'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 162466,
#  'explicit': False,
#  'external_ids': {'isrc': 'USSM11505220'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6RB9YvNyP0RZfCUcMtZELH'},
#  'href': 'https://api.spotify.com/v1/tracks/6RB9YvNyP0RZfCUcMtZELH',
#  'id': '6RB9YvNyP0RZfCUcMtZELH',
#  'is_local': False,
#  'name': 'Freedom',
#  'popularity': 68,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:6RB9YvNyP0RZfCUcMtZELH'}

# %%
for key in track.keys():
    print(f"{key}: {track[key]}")
# Out:
# album: {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'}, 'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8', 'id': '2RdwBSPQiwcmiDo9kixcl8', 'name': 'Pharrell Williams', 'type': 'artist', 'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/3Aw8a13WJi24hkjRRtMp9n'}, 'href': 'https://api.spotify.com/v1/albums/3Aw8a13WJi24hkjRRtMp9n', 'id': '3Aw8a13WJi24hkjRRtMp9n', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273f3e795a11fd55388843b85c9', 'width': 640, 'height': 640}, {'url': 'https://i.scdn.co/image/ab67616d00001e02f3e795a11fd55388843b85c9', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d00004851f3e795a11fd55388843b85c9', 'width': 64, 'height': 64}], 'name': 'Freedom', 'release_date': '2015-07-02', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:3Aw8a13WJi24hkjRRtMp9n'}
# artists: [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'}, 'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8', 'id': '2RdwBSPQiwcmiDo9kixcl8', 'name': 'Pharrell Williams', 'type': 'artist', 'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}]
# available_markets: ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK']
# disc_number: 1
# duration_ms: 162466
# explicit: False
# external_ids: {'isrc': 'USSM11505220'}
# external_urls: {'spotify': 'https://open.spotify.com/track/6RB9YvNyP0RZfCUcMtZELH'}
# href: https://api.spotify.com/v1/tracks/6RB9YvNyP0RZfCUcMtZELH
# id: 6RB9YvNyP0RZfCUcMtZELH
# is_local: False
# name: Freedom
# popularity: 68
# preview_url: None
# track_number: 1
# type: track
# uri: spotify:track:6RB9YvNyP0RZfCUcMtZELH
